# %% [markdown]
# ---
# title: mathematica test
# format:
#   html:
#     code-fold: true
# ---

# %%
$Version
# Out:
# 15.0.0 for Mac OS X ARM (64-bit) (May 19, 2026)

# %% [markdown]
# ## plot test
#
# will this work?

# %%
#| code-fold: true
Plot3D[
    Sin[x y],
    {x,-Pi,Pi},{y,-Pi,Pi}
    ]
# Out:
# -Graphics3D-

# %%
{Slider[Dynamic[n], {0, 100, 1}], Dynamic[n]}
# Out:
# {Slider[Dynamic[n], {0, 100, 1}], Dynamic[n]}
